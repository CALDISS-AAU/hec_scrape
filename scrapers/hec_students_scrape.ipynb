# %% [markdown]
# ### Libraries
#
# Importing libraries...

# %%
import scrapy
import requests
from scrapy import Selector

from bs4 import BeautifulSoup

import os
import sys

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.firefox.firefox_binary import FirefoxBinary
from selenium.common.exceptions import NoSuchElementException, WebDriverException, ElementNotInteractableException
from selenium.webdriver.common.action_chains import ActionChains

import time

# %%
url = 'https://www.hec.gov.pk/english/services/students/PCD/Pages/PCD.aspx' #main URL
html = requests.get(url).content #extract HTML
sel = Selector(text = html) #create Selector object

# %%
table_sel = sel.css('div#MSOZoneCell_WebPartWPQ2 ::text').extract()

# %%
table_sel
# Out:
# ['\r\n\t\t',
#  '\r\n\t\t\t',
#  'Serial/PCD.No',
#  '\xa0',
#  '\xa0',
#  'Name of University',
#  '\xa0',
#  '\xa0',
#  'Name of PhD Scholar',
#  '\xa0',
#  '\xa0',
#  'Subject',
#  '\xa0',
#  '\xa0',
#  'Title of Research Dissertation',
#  '\xa0',
#  '\xa0',
#  'Enrollment-Date',
#  '\xa0',
#  '\xa0',
#  'Submission-Date',
#  '\xa0',
#  '\xa0',
#  'Notification-Date',
#  '\xa0',
#  '\xa0',
#  'Name of Supervisor',
#  '\xa0',
#  '\xa0',
#  'HEC Approved Supervisor',
#  '\xa0',
#  '\xa0',
#  'Name & County External Reviewer-1',
#  '\xa0',
#  '\xa0',
#  'Name & Country External Reviewer-2',
#  '\xa0',
#  '\xa0',
#  'Title of Research Paper',
#  '\xa0',
#  '\xa0',
#  'Subject discipline',
#  '\xa0',
#  '\xa0',
#  'Name of journal',
#  '\xa0',
#  '\xa0',
#  'Category of  Journal at Publication time',
#  '\xa0',
#  '\xa0',
#  'Publication Date',
#  '\xa0',
#  '\xa0',
#  'Admission Test GAT/GRE',
#  '\xa0',
#  '\xa0',
#  '19262',
#  'Government College University, Lahore.',
#  'Aneel Samuel',
#  'Urdu',
#  'عبداللہ حسین کی فکشن میں عصری حسیت',
#  '7-May-2012',
#  '5-Nov-2018',
#  '30-May-2019',
#  'Dr. Muhammad Saeed',
#  'No',
#  'Dr. Abdul Haq, India',
#  'Dr. Nadim Ahmad, India',
#  'Abdullah Hussain ka Afsana "Samundar" or Aalmi Hesiyat',
#  'Social Sciences',
#  'ALHAMD',
#  'Z',
#  'Jan-June 2018',
#  '19261',
#  'University of Agriculture, Faisalabad.',
#  'Nida Firdous',
#  'Food Technology',
#  'Development and Evaluation of Aloevera gel based edible coating for shelf life extension of tomatoes',
#  '16-Sep-2013',
#  '13-Feb-2018',
#  '27-Jun-2019',
#  'Dr. Moazzam Rafiq Khan',
#  'Yes',
#  'Dr. Cindy Tong, USA',
#  'Hang Xiao, Ph.D., USA',
#  'Application of Aloevera gel based edible coating to maintain postharvest quality of Tomatoes',
#  'Sciences',
#  '-',
#  'W',
#  '3-Apr-2019',
#  '1 - 2',
#  'Compliance Details',
#  "javascript:commonShowModalDialog('{SiteUrl}'+ \r\n            '/_layouts/15/itemexpiration.aspx' \r\n            +'?ID={ItemId}&List={ListId}', 'center:1;dialogHeight:500px;dialogWidth:500px;resizable:yes;status:no;location:no;menubar:no;help:no', function GotoPageAfterClose(pageid){if(pageid == 'hold') {STSNavigate(unescape(decodeURI('{SiteUrl}'))+ \r\n            '/_layouts/15/hold.aspx' \r\n            +'?ID={ItemId}&List={ListId}');  return false;} if(pageid == 'audit') {STSNavigate(unescape(decodeURI('{SiteUrl}'))+\r\n            '/_layouts/15/Reporting.aspx'\r\n            +'?Category=Auditing&backtype=item&ID={ItemId}&List={ListId}'); return false;} if(pageid == 'config') {STSNavigate(unescape(decodeURI('{SiteUrl}'))+\r\n            '/_layouts/15/expirationconfig.aspx'\r\n            +'?ID={ItemId}&List={ListId}'); return false;}}, null);",
#  '0x0',
#  '0x1',
#  'ContentType',
#  '0x01',
#  '898',
#  'Document Set Version History',
#  '/_layouts/15/images/versions.gif?rev=23',
#  "javascript:SP.UI.ModalDialog.ShowPopupDialog('{SiteUrl}'+ \r\n                '/_layouts/15/DocSetVersions.aspx'\r\n                + '?List={ListId}&ID={ItemId}')",
#  '0x0',
#  '0x0',
#  'ContentType',
#  '0x0120D520',
#  '330',
#  'Send To other location',
#  '/_layouts/15/images/sendOtherLoc.gif?rev=23',
#  "javascript:GoToPage('{SiteUrl}' +\r\n                '/_layouts/15/docsetsend.aspx' \r\n                + '?List={ListId}&ID={ItemId}')",
#  '0x0',
#  '0x0',
#  'ContentType',
#  '0x0120D520',
#  '350',
#  '\r\n\t\t',
#  '\r\n\t']

# %%
## With chrome
driver = webdriver.Chrome(executable_path = 'C:\\bin\\chromedriver')

driver.get(url)
time.sleep(5)

driver.find_element_by_css_selector("#bottomPagingCellWPQ2 > table:nth-child(1) > tbody:nth-child(1) > tr:nth-child(1) > td:nth-child(2) > a:nth-child(1) > img:nth-child(1)").click()
time.sleep(3)

driver.find_element_by_css_selector("#bottomPagingCellWPQ2 > table:nth-child(1) > tbody:nth-child(1) > tr:nth-child(1) > td:nth-child(3) > a:nth-child(1) > img:nth-child(1)").click()
time.sleep(3)

driver.find_element_by_css_selector("#bottomPagingCellWPQ2 > table:nth-child(1) > tbody:nth-child(1) > tr:nth-child(1) > td:nth-child(3) > a:nth-child(1) > img:nth-child(1)").click()
time.sleep(3)

driver.find_element_by_css_selector("#bottomPagingCellWPQ2 > table:nth-child(1) > tbody:nth-child(1) > tr:nth-child(1) > td:nth-child(3) > a:nth-child(1) > img:nth-child(1)").click()
time.sleep(3)

#pageSource = {}
#pageno = 1
#pagestr = "page_" + str(pageno)
#pageSources[pagestr] = driver.page_source

#while True:
#    try:
#        driver.find_element_by_css_selector("button.next").click()
#        time.sleep(4)
#    except (NoSuchElementException, WebDriverException, ElementNotInteractableException) as e:
#        print("No 'Next' button found")
#        break
        
pageSource = driver.page_source

## Text extraction should occur with each page! (inside while loop)

driver.quit()

# %%
sel = Selector(text = pageSource) #create Selector object
table_sel = sel.css('div#MSOZoneCell_WebPartWPQ2 ::text').extract()

# %%
table_sel
# Out:
# ['\n\t\t',
#  '\n\t\t\t',
#  'Serial/PCD.No',
#  '\xa0',
#  '\xa0',
#  'Name of University',
#  '\xa0',
#  '\xa0',
#  'Name of PhD Scholar',
#  '\xa0',
#  '\xa0',
#  'Subject',
#  '\xa0',
#  '\xa0',
#  'Title of Research Dissertation',
#  '\xa0',
#  '\xa0',
#  'Enrollment-Date',
#  '\xa0',
#  '\xa0',
#  'Submission-Date',
#  '\xa0',
#  '\xa0',
#  'Notification-Date',
#  '\xa0',
#  '\xa0',
#  'Name of Supervisor',
#  '\xa0',
#  '\xa0',
#  'HEC Approved Supervisor',
#  '\xa0',
#  '\xa0',
#  'Name & County External Reviewer-1',
#  '\xa0',
#  '\xa0',
#  'Name & Country External Reviewer-2',
#  '\xa0',
#  '\xa0',
#  'Title of Research Paper',
#  '\xa0',
#  '\xa0',
#  'Subject discipline',
#  '\xa0',
#  '\xa0',
#  'Name of journal',
#  '\xa0',
#  '\xa0',
#  'Category of  Journal at Publication time',
#  '\xa0',
#  '\xa0',
#  'Publication Date',
#  '\xa0',
#  '\xa0',
#  'Admission Test GAT/GRE',
#  '\xa0',
#  '\xa0',
#  '19254',
#  'University of Peshawar, Peshawar.',
#  'Muhammad Hassan',
#  'Pharmacy',
#  'Fabrication, Characterization, In-Vitro and In-Vivo Evaluation of Etoposide Loaded Polymeric Nanoparticles',
#  '8-Mar-2012',
#  '8-Mar-2019',
#  '30-Oct-2019',
#  'Dr. Zafar Iqbal TI',
#  'Yes',
#  'Franco DOSIO, Italy',
#  'S. Kamal Jonnalagadda PhD, USA',
#  'Simultaneous Determination of Etoposide and Paclitaxel in Biological and Pharmaceutical Samples by RP-HPLC; Method Development, Validation and Applications of the method for Evaluation of Polymeric Nanoparticles',
#  'Sciences',
#  'Journal of Chemical Society of Pakistan',
#  'W (IF)',
#  '2-Oct-2019',
#  '19253',
#  'University of Peshawar, Peshawar.',
#  'Muhammad Qasim',
#  'Economics',
#  'An Assessment of Inland Destructive Fishing Practices in District Charsadda, Pakistan',
#  '23-Sep-2014',
#  '15-May-2018',
#  '31-Oct-2019',
#  'Muhammad Naeem',
#  'No',
#  'Muhammad Azeem Qureshi, Norway',
#  'Abdelhak Senadjki, PhD, Malaysia',
#  'Drivers of Destructive Fishing Practices in District Charsadda, Khyber Pakhtunkhawa Province of Pakistan',
#  'Social Sciences',
#  'The Dialogue',
#  'Y',
#  '19-Oct-2019',
#  '9 - 10',
#  'Compliance Details',
#  "javascript:commonShowModalDialog('{SiteUrl}'+ \n            '/_layouts/15/itemexpiration.aspx' \n            +'?ID={ItemId}&List={ListId}', 'center:1;dialogHeight:500px;dialogWidth:500px;resizable:yes;status:no;location:no;menubar:no;help:no', function GotoPageAfterClose(pageid){if(pageid == 'hold') {STSNavigate(unescape(decodeURI('{SiteUrl}'))+ \n            '/_layouts/15/hold.aspx' \n            +'?ID={ItemId}&List={ListId}');  return false;} if(pageid == 'audit') {STSNavigate(unescape(decodeURI('{SiteUrl}'))+\n            '/_layouts/15/Reporting.aspx'\n            +'?Category=Auditing&backtype=item&ID={ItemId}&List={ListId}'); return false;} if(pageid == 'config') {STSNavigate(unescape(decodeURI('{SiteUrl}'))+\n            '/_layouts/15/expirationconfig.aspx'\n            +'?ID={ItemId}&List={ListId}'); return false;}}, null);",
#  '0x0',
#  '0x1',
#  'ContentType',
#  '0x01',
#  '898',
#  'Document Set Version History',
#  '/_layouts/15/images/versions.gif?rev=23',
#  "javascript:SP.UI.ModalDialog.ShowPopupDialog('{SiteUrl}'+ \n                '/_layouts/15/DocSetVersions.aspx'\n                + '?List={ListId}&ID={ItemId}')",
#  '0x0',
#  '0x0',
#  'ContentType',
#  '0x0120D520',
#  '330',
#  'Send To other location',
#  '/_layouts/15/images/sendOtherLoc.gif?rev=23',
#  "javascript:GoToPage('{SiteUrl}' +\n                '/_layouts/15/docsetsend.aspx' \n                + '?List={ListId}&ID={ItemId}')",
#  '0x0',
#  '0x0',
#  'ContentType',
#  '0x0120D520',
#  '350',
#  '\n\t\t',
#  '\n\t']
